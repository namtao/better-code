# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\vanna\.conda\envs\.env\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (1.4.1.post1)
# Requirement already satisfied: joblib>=0.14 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (0.59.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (4.10.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\vanna\appdata\roaming\python\python312\site-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\vanna\appdata\roaming\python\python312\site-packages (from pooch>=1.0->librosa) (24.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.3.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\vanna\.conda\envs\.env\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vanna\.conda\envs\.env\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)

# %%
import librosa

# filename = librosa.example('nutcracker')
filename = 'sources/data.wav'

audio, sr = librosa.load(filename)

# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.linspace(0, audio.shape[0] / sr, num = audio.shape[0])
plt.plot(time, audio, color = 'blue')
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (quantized)")
plt.title("Wav file visualization")
plt.axhline(y = 0, color = 'r', linestyle = '-')
plt.show()

# %%
# !pip install SpeechRecognition

# %%
import speech_recognition as sr

r = sr.Recognizer()
audio_filename = 'data.wav'
my_audio = sr.AudioFile(audio_filename)
with my_audio as source:
    audio = r.record(source)

print(type(audio))
your_speech = r.recognize_google(audio, language = "vi-VN")
print("Audio transcription: ", your_speech)
# Out:
# <class 'speech_recognition.audio.AudioData'>
# Audio transcription:  hiện ra tận phía xa

# %%
# !pip install gtts

# %%
from gtts import gTTS
import librosa
import numpy as np

lang = 'vi'
output_filename = 'record.mp3'
content = "Tôi yêu AIO"
output = gTTS(content, lang=lang, slow = False)
output.save(output_filename)
data, sr = librosa.load(output_filename)

import IPython
IPython.display.display(IPython.display.Audio(np.transpose(data), rate = sr))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
